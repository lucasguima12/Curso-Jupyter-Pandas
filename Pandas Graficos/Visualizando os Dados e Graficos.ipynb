# %%
import pandas as pd

# %%
notas = pd.read_csv('dados/ratings.csv')

# %%
notas
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
notas.columns = ['usuarioId', 'filmesId', 'nota', 'momento']

# %%
notas
# Out:
#         usuarioId  filmesId  nota     momento
# 0               1         1   4.0   964982703
# 1               1         3   4.0   964981247
# 2               1         6   4.0   964982224
# 3               1        47   5.0   964983815
# 4               1        50   5.0   964982931
# ...           ...       ...   ...         ...
# 100831        610    166534   4.0  1493848402
# 100832        610    168248   5.0  1493850091
# 100833        610    168250   5.0  1494273047
# 100834        610    168252   5.0  1493846352
# 100835        610    170875   3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
notas['nota'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
notas.nota.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
import seaborn as sns

sns.boxplot(notas['nota'])
# Out:
# C:\Users\lucas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='nota'>

# %%
filmes = pd.read_csv('dados/movies.csv')
filmes.columns = ['filmesId', 'titulo', 'generos']

# %%
filmes
# Out:
#       filmesId                                     titulo  \
# 0            1                           Toy Story (1995)
# 1            2                             Jumanji (1995)
# 2            3                    Grumpier Old Men (1995)
# 3            4                   Waiting to Exhale (1995)
# 4            5         Father of the Bride Part II (1995)
# ...        ...                                        ...
# 9737    193581  Black Butler: Book of the Atlantic (2017)
# 9738    193583               No Game No Life: Zero (2017)
# 9739    193585                               Flint (2017)
# 9740    193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741    193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                           generos
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
notas.head()
# Out:
#    usuarioId  filmesId  nota    momento
# 0          1         1   4.0  964982703
# 1          1         3   4.0  964981247
# 2          1         6   4.0  964982224
# 3          1        47   5.0  964983815
# 4          1        50   5.0  964982931

# %%
notas.query('filmesId== 1').nota.mean()        ##query é como se fosse uma pergunta
# Out:
# 3.9209302325581397

# %%
notas.query('filmesId== 2').nota.mean()
# Out:
# 3.4318181818181817

# %%
filmes_id = notas.groupby("filmesId").mean()

# %%
medias_por_filme = filmes_id['nota']

# %%
medias_por_filme.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.boxplot(medias_por_filme)
# Out:
# C:\Users\lucas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='nota'>

# %%
sns.displot(medias_por_filme)

# %%
medias_por_filme.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: nota, dtype: float64

# %% [markdown]
# # EXTRA

# %%
notas
# Out:
#         usuarioId  filmesId  nota     momento
# 0               1         1   4.0   964982703
# 1               1         3   4.0   964981247
# 2               1         6   4.0   964982224
# 3               1        47   5.0   964983815
# 4               1        50   5.0   964982931
# ...           ...       ...   ...         ...
# 100831        610    166534   4.0  1493848402
# 100832        610    168248   5.0  1493850091
# 100833        610    168250   5.0  1494273047
# 100834        610    168252   5.0  1493846352
# 100835        610    170875   3.0  1493846415
#
# [100836 rows x 4 columns]

# %% [markdown]
# ## Juntando as notas com o dataframe de filmes

# %%
filmes
# Out:
#       filmesId                                     titulo  \
# 0            1                           Toy Story (1995)
# 1            2                             Jumanji (1995)
# 2            3                    Grumpier Old Men (1995)
# 3            4                   Waiting to Exhale (1995)
# 4            5         Father of the Bride Part II (1995)
# ...        ...                                        ...
# 9737    193581  Black Butler: Book of the Atlantic (2017)
# 9738    193583               No Game No Life: Zero (2017)
# 9739    193585                               Flint (2017)
# 9740    193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741    193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                           generos
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
novo = pd.merge(filmes, notas, on = 'filmesId')

# %%
novo = novo[['usuarioId', 'filmesId', 'titulo', 'generos', 'momento', 'nota']]

# %%
novo
# Out:
#         usuarioId  filmesId                                     titulo  \
# 0               1         1                           Toy Story (1995)
# 1               5         1                           Toy Story (1995)
# 2               7         1                           Toy Story (1995)
# 3              15         1                           Toy Story (1995)
# 4              17         1                           Toy Story (1995)
# ...           ...       ...                                        ...
# 100831        184    193581  Black Butler: Book of the Atlantic (2017)
# 100832        184    193583               No Game No Life: Zero (2017)
# 100833        184    193585                               Flint (2017)
# 100834        184    193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835        331    193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                             generos     momento  nota
# 0       Adventure|Animation|Children|Comedy|Fantasy   964982703   4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy   847434962   4.0
# 2       Adventure|Animation|Children|Comedy|Fantasy  1106635946   4.5
# 3       Adventure|Animation|Children|Comedy|Fantasy  1510577970   2.5
# 4       Adventure|Animation|Children|Comedy|Fantasy  1305696483   4.5
# ...                                             ...         ...   ...
# 100831              Action|Animation|Comedy|Fantasy  1537109082   4.0
# 100832                     Animation|Comedy|Fantasy  1537109545   3.5
# 100833                                        Drama  1537109805   3.5
# 100834                             Action|Animation  1537110021   3.5
# 100835                                       Comedy  1537157606   4.0
#
# [100836 rows x 6 columns]

# %%
notas_filme1 = novo.loc[novo['filmesId'] == 1]        
## ou                                                       ##notas do filme id 1
notas_filme1 = novo.query('filmesId == 1')

# %%
notas_filme1
# Out:
#      usuarioId  filmesId            titulo  \
# 0            1         1  Toy Story (1995)
# 1            5         1  Toy Story (1995)
# 2            7         1  Toy Story (1995)
# 3           15         1  Toy Story (1995)
# 4           17         1  Toy Story (1995)
# ..         ...       ...               ...
# 210        606         1  Toy Story (1995)
# 211        607         1  Toy Story (1995)
# 212        608         1  Toy Story (1995)
# 213        609         1  Toy Story (1995)
# 214        610         1  Toy Story (1995)
#
#                                          generos     momento  nota
# 0    Adventure|Animation|Children|Comedy|Fantasy   964982703   4.0
# 1    Adventure|Animation|Children|Comedy|Fantasy   847434962   4.0
# 2    Adventure|Animation|Children|Comedy|Fantasy  1106635946   4.5
# 3    Adventure|Animation|Children|Comedy|Fantasy  1510577970   2.5
# 4    Adventure|Animation|Children|Comedy|Fantasy  1305696483   4.5
# ..                                           ...         ...   ...
# 210  Adventure|Animation|Children|Comedy|Fantasy  1349082950   2.5
# 211  Adventure|Animation|Children|Comedy|Fantasy   964744033   4.0
# 212  Adventure|Animation|Children|Comedy|Fantasy  1117408267   2.5
# 213  Adventure|Animation|Children|Comedy|Fantasy   847221025   3.0
# 214  Adventure|Animation|Children|Comedy|Fantasy  1479542900   5.0
#
# [215 rows x 6 columns]

# %%
notas_usuario1 = novo.loc[novo['usuarioId'] == 1]   ## notas do usuario 1
notas_usuario1
# Out:
#        usuarioId  filmesId                          titulo  \
# 0              1         1                Toy Story (1995)
# 325            1         3         Grumpier Old Men (1995)
# 433            1         6                     Heat (1995)
# 2107           1        47     Seven (a.k.a. Se7en) (1995)
# 2379           1        50      Usual Suspects, The (1995)
# ...          ...       ...                             ...
# 56816          1      3744                    Shaft (2000)
# 57276          1      3793                    X-Men (2000)
# 57457          1      3809          What About Bob? (1991)
# 59170          1      4006  Transformers: The Movie (1986)
# 65533          1      5060    M*A*S*H (a.k.a. MASH) (1970)
#
#                                            generos    momento  nota
# 0      Adventure|Animation|Children|Comedy|Fantasy  964982703   4.0
# 325                                 Comedy|Romance  964981247   4.0
# 433                          Action|Crime|Thriller  964982224   4.0
# 2107                              Mystery|Thriller  964983815   5.0
# 2379                        Crime|Mystery|Thriller  964982931   5.0
# ...                                            ...        ...   ...
# 56816                        Action|Crime|Thriller  964980694   4.0
# 57276                      Action|Adventure|Sci-Fi  964981855   5.0
# 57457                                       Comedy  964981220   4.0
# 59170          Adventure|Animation|Children|Sci-Fi  964982903   4.0
# 65533                             Comedy|Drama|War  964984002   5.0
#
# [232 rows x 6 columns]

# %%
notas_usuario1.index = range(notas_usuario1.shape[0])   ## notas usuairo 1 com index arrumado
notas_usuario1
# Out:
#      usuarioId  filmesId                          titulo  \
# 0            1         1                Toy Story (1995)
# 1            1         3         Grumpier Old Men (1995)
# 2            1         6                     Heat (1995)
# 3            1        47     Seven (a.k.a. Se7en) (1995)
# 4            1        50      Usual Suspects, The (1995)
# ..         ...       ...                             ...
# 227          1      3744                    Shaft (2000)
# 228          1      3793                    X-Men (2000)
# 229          1      3809          What About Bob? (1991)
# 230          1      4006  Transformers: The Movie (1986)
# 231          1      5060    M*A*S*H (a.k.a. MASH) (1970)
#
#                                          generos    momento  nota
# 0    Adventure|Animation|Children|Comedy|Fantasy  964982703   4.0
# 1                                 Comedy|Romance  964981247   4.0
# 2                          Action|Crime|Thriller  964982224   4.0
# 3                               Mystery|Thriller  964983815   5.0
# 4                         Crime|Mystery|Thriller  964982931   5.0
# ..                                           ...        ...   ...
# 227                        Action|Crime|Thriller  964980694   4.0
# 228                      Action|Adventure|Sci-Fi  964981855   5.0
# 229                                       Comedy  964981220   4.0
# 230          Adventure|Animation|Children|Sci-Fi  964982903   4.0
# 231                             Comedy|Drama|War  964984002   5.0
#
# [232 rows x 6 columns]

# %% [markdown]
# ## Fazendo media de notas

# %%
notas.head()
# Out:
#    usuarioId  filmesId  nota    momento
# 0          1         1   4.0  964982703
# 1          1         3   4.0  964981247
# 2          1         6   4.0  964982224
# 3          1        47   5.0  964983815
# 4          1        50   5.0  964982931

# %%
notas.query('filmesId == 1')
# Out:
#        usuarioId  filmesId  nota     momento
# 0              1         1   4.0   964982703
# 516            5         1   4.0   847434962
# 874            7         1   4.5  1106635946
# 1434          15         1   2.5  1510577970
# 1667          17         1   4.5  1305696483
# ...          ...       ...   ...         ...
# 97364        606         1   2.5  1349082950
# 98479        607         1   4.0   964744033
# 98666        608         1   2.5  1117408267
# 99497        609         1   3.0   847221025
# 99534        610         1   5.0  1479542900
#
# [215 rows x 4 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt 

filme1 = np.append(np.array([2.5]* 10), np.array([3.5]* 10))
filme2 = np.append(np.array([5]* 10), np.array([1]* 10))

# %%
plt.hist(filme1)
plt.hist(filme2)
# Out:
# (array([10.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0., 10.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot([filme1, filme2])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a5ec84d820>,
#   <matplotlib.lines.Line2D at 0x2a5ec84daf0>,
#   <matplotlib.lines.Line2D at 0x2a5ec85cc10>,
#   <matplotlib.lines.Line2D at 0x2a5ec85cee0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2a5ec84ddc0>,
#   <matplotlib.lines.Line2D at 0x2a5ec85c0d0>,
#   <matplotlib.lines.Line2D at 0x2a5ec86a1f0>,
#   <matplotlib.lines.Line2D at 0x2a5ec86a4c0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2a5ec84d5b0>,
#   <matplotlib.lines.Line2D at 0x2a5ec85c940>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a5ec85c3a0>,
#   <matplotlib.lines.Line2D at 0x2a5ec86a790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a5ec85c670>,
#   <matplotlib.lines.Line2D at 0x2a5ec86aa60>],
#  'means': []}

# %%
sns.boxplot(x = 'filmesId', y = 'nota', data = notas.query('filmesId in [1,2]'))
# Out:
# <AxesSubplot:xlabel='filmesId', ylabel='nota'>
